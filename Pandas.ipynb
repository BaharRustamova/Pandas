# %%
import pandas as pd
nd=pd.read_csv('C:/Users/user/Downloads/train (1).csv')

# %%
#1. Show first 7 observations in dataset.
nd.head(7)
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
# 5  train_5       0  11.4763 -2.3182  12.6080  8.6264  10.9621  3.5609  4.5322
# 6  train_6       0  11.8091 -0.0832   9.3494  4.2916  11.1355 -8.0198  6.1961
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# ...

# %%
#2. Check if there are any missing values.
nd.isnull().any()
# Out:
# ID_code    False
# target     False
# var_0      False
# var_1      False
# var_2      False
#            ...
# var_195    False
# var_196    False
# var_197    False
# var_198    False
# var_199    False
# Length: 202, dtype: bool

# %%
nd.isnull().sum()
# Out:
# ID_code    0
# target     0
# var_0      0
# var_1      0
# var_2      0
#           ..
# var_195    0
# var_196    0
# var_197    0
# var_198    0
# var_199    0
# Length: 202, dtype: int64

# %%
#3. Find mean of each variable according to target.
numeric_nd = nd.select_dtypes(include=['number'])
mean_values = numeric_nd.mean()
print(mean_values)
# Out:
# target      0.100490
# var_0      10.679914
# var_1      -1.627622
# var_2      10.715192
# var_3       6.796529
#              ...
# var_195    -0.142088
# var_196     2.303335
# var_197     8.908158
# var_198    15.870720
# var_199    -3.326537
# Length: 201, dtype: float64

# %%
#4.Count number of values for each target.
nd.count()
# Out:
# ID_code    200000
# target     200000
# var_0      200000
# var_1      200000
# var_2      200000
#             ...
# var_195    200000
# var_196    200000
# var_197    200000
# var_198    200000
# var_199    200000
# Length: 202, dtype: int64

# %%
#5. Remove ID_code column.
nd = nd.drop(columns=['ID_code'])

# %%
#6. Get statistical summary for each variable.
#a. Give interpretation for std, min, max, mean.
#b. Show mean of var_0 by using indexing.

var_0_min = nd['var_0'].min()
var_0_mean = nd['var_0'].mean()

# %%
print(nd.describe())
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
#7. Filter var_0 variable from minimum to mean.
filtered_nd = nd[(nd['var_0'] >= var_0_min) & (nd['var_0'] <= var_0_mean)]
filtered_nd
# Out:
#         target   var_0   var_1    var_2   var_3    var_4    var_5   var_6  \
# 0            0  8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834  5.1187
# 2            0  8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427
# 4            0  9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486  5.9405
# 10           0  5.0702 -0.5447   9.5900  4.2987  12.3910 -18.8687  6.0382
# 12           0  8.7671 -4.6154   9.7242  7.4242   9.0254   1.4247  6.2815
# ...        ...     ...     ...      ...     ...      ...      ...     ...
# 199985       0  9.0249 -3.6379  12.3907  5.1915  12.1701  -8.8978  5.2574
# 199987       0  8.0438 -1.9184  13.1498  9.2027   8.9886   2.7531  4.2194
# 199991       0  9.9909  2.5523  11.9653  6.3958  13.5497  -9.5293  6.0864
# 199996       0  4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628  5.8802
# 199998       0  9.7148 -8.6098  13.6104  5.7930  12.5173   0.5339  6.0479
#
#           var_7   var_8  ...  var_190  var_191  var_192  var_193  var_194  \
# ...

# %%
# 8.Filter var_6 greater than 5 and var_196 less than 2.

filtered_nd = nd[(nd['var_6'] > 5) & (nd['var_196'] < 2)]
filtered_nd
# Out:
#         target    var_0   var_1    var_2   var_3    var_4    var_5   var_6  \
# 2            0   8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427
# 3            0  11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361  5.8428
# 11           0  12.7188 -7.9750  10.3757  9.0101  12.8570 -12.0852  5.6464
# 14           0  13.8080  5.0514  17.2611  8.5120  12.8517  -9.1622  5.7327
# 16           0   5.0615  0.2689  15.1325  3.6587  13.5276  -6.5477  5.2757
# ...        ...      ...     ...      ...     ...      ...      ...     ...
# 199990       1  14.1475  1.8568  11.0066  3.6779  12.1944 -16.5936  5.3217
# 199991       0   9.9909  2.5523  11.9653  6.3958  13.5497  -9.5293  6.0864
# 199994       0  12.3925 -5.8821  11.2323  3.9237  10.4509  10.7262  7.0503
# 199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628  5.8802
# 199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488  5.2839
#
# ...

# %%
nd.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import seaborn as sns

# %%
group1 = nd.iloc[:, :20]  
group2 = nd.iloc[:, 20:40]  

plt.figure(figsize=(20, 8))
group1.boxplot()
plt.title("Group 1")
plt.xticks(rotation=90)
plt.show()

plt.figure(figsize=(20, 8))
group2.boxplot()
plt.title("Group 2")
plt.xticks(rotation=90)
plt.show()

# %%
df1=nd.drop(['target'], axis=1).transpose()

# %%
#9. Show observations between 20000 and 30000 for 11th column.
filtered_rows = nd[(nd.iloc[:, 10] >= 19999) & (nd.iloc[:, 10] <= 30000)]
filtered_rows
# Out:
# Empty DataFrame
# Columns: [target, var_0, var_1, var_2, var_3, var_4, var_5, var_6, var_7, var_8, var_9, var_10, var_11, var_12, var_13, var_14, var_15, var_16, var_17, var_18, var_19, var_20, var_21, var_22, var_23, var_24, var_25, var_26, var_27, var_28, var_29, var_30, var_31, var_32, var_33, var_34, var_35, var_36, var_37, var_38, var_39, var_40, var_41, var_42, var_43, var_44, var_45, var_46, var_47, var_48, var_49, var_50, var_51, var_52, var_53, var_54, var_55, var_56, var_57, var_58, var_59, var_60, var_61, var_62, var_63, var_64, var_65, var_66, var_67, var_68, var_69, var_70, var_71, var_72, var_73, var_74, var_75, var_76, var_77, var_78, var_79, var_80, var_81, var_82, var_83, var_84, var_85, var_86, var_87, var_88, var_89, var_90, var_91, var_92, var_93, var_94, var_95, var_96, var_97, var_98, ...]
# Index: []
#
# [0 rows x 201 columns]

# %%
#10. Create features list including variables from var_0 to var_9.
#a. Find correlations in features.
#b. Sort most correlated variables in features.
#c. Show top 10 most correlated variables in features.

#10
features=nd.columns[1:12]
df2=nd[features]
df2
# Out:
#           var_0   var_1    var_2   var_3    var_4    var_5   var_6    var_7  \
# 0        8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834  5.1187  18.6266
# 1       11.5006 -4.1473  13.8588  5.3890  12.3622   7.0433  5.6208  16.5338
# 2        8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427  14.6155
# 3       11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361  5.8428  14.9250
# 4        9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486  5.9405  19.2514
# ...         ...     ...      ...     ...      ...      ...     ...      ...
# 199995  11.4880 -0.4956   8.2622  3.5142  10.3404  11.6081  5.6709  15.1516
# 199996   4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628  5.8802  21.5940
# 199997  11.2232 -5.0518  10.5127  5.6456   9.3410  -5.4086  4.5555  21.5571
# 199998   9.7148 -8.6098  13.6104  5.7930  12.5173   0.5339  6.0479  17.0152
# 199999  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488  5.2839  15.2058
#
#          var_8   var_9  var_10
# ...

# %%
#10.a
df2.corr().abs()
# Out:
#            var_0     var_1     var_2     var_3     var_4     var_5     var_6  \
# var_0   1.000000  0.000544  0.006573  0.003801  0.001326  0.003046  0.006983
# var_1   0.000544  1.000000  0.003980  0.000010  0.000303  0.000902  0.003258
# var_2   0.006573  0.003980  1.000000  0.001001  0.000723  0.001569  0.000883
# var_3   0.003801  0.000010  0.001001  1.000000  0.000322  0.003253  0.000774
# var_4   0.001326  0.000303  0.000723  0.000322  1.000000  0.001368  0.000049
# var_5   0.003046  0.000902  0.001569  0.003253  0.001368  1.000000  0.002588
# var_6   0.006983  0.003258  0.000883  0.000774  0.000049  0.002588  1.000000
# var_7   0.002429  0.001511  0.000991  0.002500  0.004549  0.000995  0.002548
# var_8   0.004962  0.004098  0.002648  0.003553  0.001194  0.000147  0.001188
# var_9   0.002613  0.000832  0.001932  0.000826  0.000918  0.005279  0.005697
# var_10  0.000355  0.002875  0.000474  0.000897  0.003445  0.000332  0.001503
#
# ...

# %%
df2.corr().abs().unstack()
# Out:
# var_0   var_0     1.000000
#         var_1     0.000544
#         var_2     0.006573
#         var_3     0.003801
#         var_4     0.001326
#                     ...
# var_10  var_6     0.001503
#         var_7     0.000359
#         var_8     0.000750
#         var_9     0.001553
#         var_10    1.000000
# Length: 121, dtype: float64

# %%
#10.b
df2.corr().abs().unstack().sort_values(ascending=False)[10:30:2]
# Out:
# var_10  var_10    1.000000
# var_6   var_0     0.006983
# var_2   var_0     0.006573
# var_9   var_6     0.005697
# var_5   var_9     0.005279
# var_8   var_0     0.004962
# var_4   var_7     0.004549
# var_8   var_1     0.004098
# var_1   var_2     0.003980
# var_0   var_3     0.003801
# dtype: float64

# %%
#11. Remove outliers from dataset.
df1=nd.drop(['target'],axis=1)

# %%
q25=df1.quantile(0.25)
q75=df1.quantile(0.75)
iqr=q75-q25
iqr
# Out:
# var_0       4.304350
# var_1       6.098650
# var_2       3.794225
# var_3       3.070025
# var_4       2.377950
#              ...
# var_195     2.000300
# var_196     8.503650
# var_197     1.340500
# var_198     4.235025
# var_199    16.045275
# Length: 200, dtype: float64

# %%
df1[((df1<q25-1.5*iqr) | (df1<q75+1.5*iqr)).any(axis=1)]
# Out:
#           var_0   var_1    var_2   var_3    var_4    var_5   var_6    var_7  \
# 0        8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834  5.1187  18.6266
# 1       11.5006 -4.1473  13.8588  5.3890  12.3622   7.0433  5.6208  16.5338
# 2        8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427  14.6155
# 3       11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361  5.8428  14.9250
# 4        9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486  5.9405  19.2514
# ...         ...     ...      ...     ...      ...      ...     ...      ...
# 199995  11.4880 -0.4956   8.2622  3.5142  10.3404  11.6081  5.6709  15.1516
# 199996   4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628  5.8802  21.5940
# 199997  11.2232 -5.0518  10.5127  5.6456   9.3410  -5.4086  4.5555  21.5571
# 199998   9.7148 -8.6098  13.6104  5.7930  12.5173   0.5339  6.0479  17.0152
# 199999  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488  5.2839  15.2058
#
# ...
